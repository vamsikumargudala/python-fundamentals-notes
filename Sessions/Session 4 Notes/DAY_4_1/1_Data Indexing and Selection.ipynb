# %% [markdown]
# <center> <img src ="https://i.postimg.cc/1X8H7YYt/BITS-Logo.png" width = "400" alt="BITS Pilani Logo" /> </center>

# %% [markdown]
# <font color='green'> <h1> <center> Data Indexing and Selection </center> </h1> </font>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Mount Google Drive
#
# First, we need to mount your Google Drive to access files stored there. This will prompt you to authorize Colab to access your Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Read `students.csv` from Google Drive
#
# Now that your Drive is mounted, please provide the full path to your `students.csv` file within your Google Drive (e.g., `/content/drive/MyDrive/my_data/students.csv`).

# %%
import pandas as pd

variable_name = ""
data_frame1 = "/content/drive/MyDrive/Introduction_Python/DAY_4/DAY_4_1/students.csv" # Replace with the actual path to your students.csv file on Google Drive

try:
    df_from_drive = pd.read_csv(data_frame1)
    print(f"Successfully loaded")
    # display(df_from_drive.head())
except FileNotFoundError:
    print(f"Error: The file was not found. Please ensure the path is correct.")
except Exception as e:
    print(f"An error occurred while reading the file")
# Out:
# Successfully loaded

# %%
data_frame = pd.read_csv("students.csv")
data_frame
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %% [markdown]
# <b> Viewing index and columns names <b>

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data_frame.columns
# Out:
# Index(['id', 'name', 'quiz1', 'quiz2', 'midsem', 'compre'], dtype='object')

# %%
data_frame.dtypes
# Out:
# id         int64
# name      object
# quiz1      int64
# quiz2      int64
# midsem     int64
# compre     int64
# dtype: object

# %% [markdown]
# <b> Viewing Data <b>

# %% [markdown]
# head() helps to view topn rows. Default is 5 rows.

# %%
data_frame.head()
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
#top n rows can be see by passing the topn value
data_frame.head(2)
# Out:
#    id   name  quiz1  quiz2  midsem  compre
# 0   1  Alice      5      4      80      70
# 1   2    Bob      4      5      75      85

# %% [markdown]
# tail() helps to view bottom n rows. Default is 5 rows.

# %%
data_frame.tail()
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
data_frame.tail(2)
# Out:
#    id   name  quiz1  quiz2  midsem  compre
# 3   4  David      5      3      65      70
# 4   5    Eve      2      5      88      92

# %% [markdown]
# <b> Column Selection<b>

# %% [markdown]
# Acceess individual columns by its name. i.e. data_frame_obj.column_name

# %%
data_frame.id # returns index and data values
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: id, dtype: int64

# %% [markdown]
# Basically its a series and then all series operations can be performed on it.

# %%
type(data_frame.id)
# Out:
# pandas.core.series.Series

# %% [markdown]
# [] operator can also be used to access the column. The result is also a series.

# %%
data_frame["name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# Name: name, dtype: object

# %%
type(data_frame["name"])

# %% [markdown]
# List of columns can be accessed as follows :

# %%
list_of_columns= ["id", "name"]
data_frame[list_of_columns]
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5      Eve

# %% [markdown]
# But this time, the outcome is data frame not a series.

# %%
type(data_frame[list_of_columns])

# %%
sub_df = data_frame[list_of_columns]
sub_df
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5      Eve

# %% [markdown]
# <b>Different Choices for Indexing<b>

# %% [markdown]
# Object selection has had a number of user-requested additions in order to support more explicit location based indexing. <br>
#
# <b>.loc </b>is primarily label based, but may also be used with a boolean array. .loc will raise KeyError when the items are not found. Allowed inputs are:<br>
#
# - A single label, e.g. 5 or 'a' (Note that 5 is interpreted as a label of the index. This use is not an integer position along the index.).
# - A list or array of labels ['a', 'b', 'c'].
# - A slice object with labels 'a':'f' (Note that contrary to usual python slices, both the start and the stop are included, when present in the index! See Slicing with labels.).
# - A boolean array<br>
#
# <b>.iloc </b>is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array. .iloc will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing. (this conforms with Python/NumPy slice semantics). Allowed inputs are: <br>
#
# - An integer e.g. 5.
# - A list or array of integers [4, 3, 0].
# - A slice object with ints 1:7.
# - A boolean array.

# %% [markdown]
# <b> Using .loc <b>

# %%
data_frame
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %% [markdown]
# Access the first row in the data frame using the index

# %%
data_frame.loc[0]
# Out:
# id            1
# name      Alice
# quiz1         5
# quiz2         4
# midsem       80
# compre       70
# Name: 0, dtype: object

# %% [markdown]
# Access the intermediate rows in the data frame using the index

# %%
data_frame.loc[1:3]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70

# %% [markdown]
# With index, column names can also be specified in order to access value for those columns only.

# %%
data_frame.loc[0, "id"]
# Out:
# np.int64(1)

# %%
data_frame.loc[0, ['id', 'name', 'quiz1']]
# Out:
# id           1
# name     Alice
# quiz1        5
# Name: 0, dtype: object

# %% [markdown]
# Other variations

# %%
#Get all the row after index 2
data_frame.loc[2:]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
#Get all the rows having index less than 3
data_frame.loc[: 3]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70

# %%
#Get alternate rows
data_frame.loc[::2]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 2   3  Charlie      3      4      90      80
# 4   5      Eve      2      5      88      92

# %%
data_frame.loc[0, 'name']
# Out:
# 'Alice'

# %%
data_frame.loc[0:2, ['id', 'name', 'quiz1']]
# Out:
#    id     name  quiz1
# 0   1    Alice      5
# 1   2      Bob      4
# 2   3  Charlie      3

# %% [markdown]
# <b> Using .iloc<b>

# %% [markdown]
# Integer indices are only used to access the values.

# %%
data_frame
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
#Access the zeroth row
data_frame.iloc[0]
# Out:
# id            1
# name      Alice
# quiz1         5
# quiz2         4
# midsem       80
# compre       70
# Name: 0, dtype: object

# %%
#Access first three rows
data_frame.iloc[0:3]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80

# %%
#Acess every alternate row
data_frame.iloc[::2]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 2   3  Charlie      3      4      90      80
# 4   5      Eve      2      5      88      92

# %%
#Acces zeroth row , zeroth column
data_frame.iloc[0, 0]
# Out:
# np.int64(1)

# %%
#Aceess first two columns of row with index 1 i.e. second row
data_frame.iloc[1, 0:2]
# Out:
# id        2
# name    Bob
# Name: 1, dtype: object

# %%
#Access explicit columns of second row
data_frame.iloc[1, [0, 2, 3]]
# Out:
# id       2
# quiz1    4
# quiz2    5
# Name: 1, dtype: object

# %% [markdown]
# <b> Filtering<b>

# %% [markdown]
# Filter conditions can be used in [] to select the few specific rows.

# %%
data_frame
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
#Access the rows which fulfills the condition
data_frame[ data_frame.quiz1 > 3]
# Out:
#    id   name  quiz1  quiz2  midsem  compre
# 0   1  Alice      5      4      80      70
# 1   2    Bob      4      5      75      85
# 3   4  David      5      3      65      70

# %%
#Access the rows which fulfills both condition
data_frame[ (data_frame.quiz1 > 3) & (data_frame.quiz2 > 3)]
# Out:
#    id   name  quiz1  quiz2  midsem  compre
# 0   1  Alice      5      4      80      70
# 1   2    Bob      4      5      75      85

# %%
#Access the rows which fulfills either of condition
data_frame[ (data_frame.quiz1 > 1) | (data_frame.quiz2 > 3)]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %%
#Access the rows which fulfills both condition (with negation)
data_frame[ ~(data_frame.quiz1 > 4)]
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 4   5      Eve      2      5      88      92

# %% [markdown]
# <b> Using isin <b>

# %%
data_frame
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92

# %% [markdown]
# DataFrame also has an isin() method. When calling isin, pass a set of values as either an array or dict. If values is an array, isin returns a DataFrame of booleans that is the same shape as the original DataFrame, with True wherever the element is in the sequence of values.

# %%
marks = [3, 4]
data_frame.isin(marks)
# Out:
#       id   name  quiz1  quiz2  midsem  compre
# 0  False  False  False   True   False   False
# 1  False  False   True  False   False   False
# 2   True  False   True   True   False   False
# 3   True  False  False   True   False   False
# 4  False  False  False  False   False   False

# %% [markdown]
# <b> The query() Method <b>

# %% [markdown]
# DataFrame objects have a query() method that allows selection using an expression.
# You can get the value of the frame where column b has values between the values of columns a and c.

# %%
data_frame.query('midsem > compre')
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 2   3  Charlie      3      4      90      80

# %%
data_frame.query('midsem > compre & quiz1 == quiz2')
# Out:
# Empty DataFrame
# Columns: [id, name, quiz1, quiz2, midsem, compre]
# Index: []

# %% [markdown]
# # Task
# Generate a pandas DataFrame with sample student data (id, name, quiz1, quiz2, midsem, compre), save it as "students.csv", load it into a DataFrame, display its overview (head, columns, dtypes), demonstrate column selection (individual and multiple), row selection using `.loc` and `.iloc` (single and sliced rows), and filter the DataFrame based on conditions (e.g., quiz scores above a threshold).

# %% [markdown]
# ## Create Sample students.csv
#
# ### Subtask:
# Generate a pandas DataFrame with sample student data (id, name, quiz1, quiz2, midsem, compre) and save it as 'students.csv' in the current directory.

# %% [markdown]
# **Reasoning**:
# First, I will create a dictionary containing sample student data for the specified columns: 'id', 'name', 'quiz1', 'quiz2', 'midsem', and 'compre'. This dictionary will serve as the raw data for our DataFrame.

# %%
import pandas as pd

student_data = {
    'id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'quiz1': [5, 4, 3, 5, 2],
    'quiz2': [4, 5, 4, 3, 5],
    'midsem': [80, 75, 90, 65, 88],
    'compre': [70, 85, 80, 70, 92]
}

# %% [markdown]
# **Reasoning**:
# Now that the student data dictionary is created, I will convert it into a pandas DataFrame.

# %%
student_df = pd.DataFrame(student_data)
student_df
# Out:
#    id     name  quiz1  quiz2  midsem  compre
# 0   1    Alice      5      4      80      70
# 1   2      Bob      4      5      75      85
# 2   3  Charlie      3      4      90      80
# 3   4    David      5      3      65      70
# 4   5      Eve      2      5      88      92
